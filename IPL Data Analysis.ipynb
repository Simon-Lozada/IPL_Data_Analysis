# %% [markdown]
# ## Dependencies and Libraries

# %%
#here we import the libraries we need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Here we import our data 
df = pd.read_csv("/home/monky/Descargas/ciencia_datos/IPL_Data_Analysis/data/deliveries.csv")
#and here we see our dataframe
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ## Indeph Analysis of David Warner(Australian Batsman) Performance

# %%
#here we create a filter(the batsman DA Warner) of my dataframe 
filter = df["batsman"] == "DA Warner"
#here we create a new dataframe with my filter 
df_warner = df[filter]
#here we can see the the rows and columns of my new dataframe 
df_warner.shape
# Out:
# (2902, 21)

# %%
#here we create a new graph with my new dataframe(df_warner)
#here we count a values of the column "dismissal_kind" and later create a graph we this data
df_warner["dismissal_kind"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %% [markdown]
# ## Score Distribution for teams by Innings

# %%
#here we can see how many times team David Warner has a score of 4
len(df_warner[df_warner["batsman_runs"] == 4])
# Out:
# 401

# %%
#Here we multiply the score by how many have the score.
401*4
# Out:
# 1604

# %%
#here we can see how many times team David Warner has a score of 4
len(df_warner[df_warner["batsman_runs"] == 6])
# Out:
# 160

# %%
# here we create a function that multiplies the score by how many have the score.
def count(df,runs):
    return len(df_warner[df_warner["batsman_runs"] == runs])*runs

# %%
# here we test our function.
#here you put the data frame and score 1 as parameters
count(df_warner,1)
# Out:
# 997

# %%
# here we test our function.
#here you put the data frame and score 2 as parameters
count(df_warner,2)
# Out:
# 414

# %%
# here we test our function.
#here you put the data frame and score 3 as parameters
count(df_warner,3)
# Out:
# 39

# %%
# here we test our function.
#here you put the data frame and score 4 as parameters
count(df_warner,4)
# Out:
# 1604

# %%
# here we test our function.
#here you put the data frame and score 6 as parameters
count(df_warner,6)
# Out:
# 960

# %%
#here we create a list with the with each final value of each type of score
#these values are the same as we get from my function
slices = [997,411,39,1604,960]

#here we create a list of the score values of each type(1,2,3,4,6)
labels = [1,2,3,4,6]

#here we crea a list,this list has a separation value of each percentage of my graph
explode = [0,0,0,0.1,0]

#here we create a graph with out data(slices), here we set the name of the percentage values(use the values of my list labels), staple the graph in percent(with the parameter autopct) and we separate the largest part a little(with the parameter explode)   
plt.pie(slices, labels = labels, autopct = "%1.1f%%",explode = explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f428888c5e0>,
# ...
#  [Text(0.7813125647138419, 0.774306577668225, '1'),
#   Text(-0.338607436827045, 1.0465873129965884, '2'),
#   Text(-0.6790818472209955, 0.8653599509885588, '3'),
#   Text(-1.1137554377978547, -0.44670888146052035, '4'),
#   Text(0.8034209102108499, -0.7513420266669301, '6')],
#  [Text(0.4261704898439137, 0.4223490423644863, '24.9%'),
#   Text(-0.18469496554202453, 0.5708658070890481, '10.2%'),
#   Text(-0.3704082803023611, 0.47201451872103195, '1.0%'),
#   Text(-0.6496906720487485, -0.26058018085197016, '40.0%'),
#   Text(0.43822958738773626, -0.40982292363650724, '23.9%')])

# %%
#here we see our dataframe
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#here we see the list of the bowling teams 
df["bowling_team"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
# here we create a dictionary with the names of the teams and their keys
Teams={"Royal Challengers Bangalore":"RCB", "Sunrisers Hyderabad":"SRH",
       "Rising Pune Supergiant":"RPS", "Mumbai Indians":"MI",
       "Kolkata Knight Riders":"KKR", "Gujarat Lions":"G1", "Kings XI Punjab":"KXIP",
       "Delhi Daredevils":"DD", "Chennai Super Kings":"CSK", "Rajasthan Royals":"RR",
       "Deccan Chargers":"DC", "Kochi Tuskers Kerala":"KTK", "Pune Warriors":"PW",
       "Rising Pune Supergiants":"PRS"}

# %%
#here we create a new column with the batting_team
df["batting_team"] = df["batting_team"].map(Teams)
#here we create a new column with the batting_team
df["bowling_team"] = df["bowling_team"].map(Teams)
#here we see the dataframe with the new columns
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
#here we can see the columns of my dataframe
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#here we create a new dataframe agrup the columns "match_id","inning","batting_team"
runs = df.groupby(["match_id","inning","batting_team"])["total_runs"].sum().reset_index()
#here we set the match_id as the index
runs.drop("match_id", axis = 1, inplace = True)
#here we see the new dataframe
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           G1         183
# ...      ...          ...         ...
# 1279       2          KKR         140
# 1280       1           G1         162
# 1281       2          SRH         163
# 1282       1          SRH         208
# 1283       2          RCB         200
#
# [1284 rows x 3 columns]

# %%
#here we create a new variable with the "inning "equal to 1 (using a "runs" dataframe)
inning1 = runs[runs["inning"] == 1]
#here we create a new variable with the "inning "equal to 2 (using a "runs" dataframe)
inning2 = runs[runs["inning"] == 2]

# %%
#here we a new graph using the labrery seaborn
#here we using the "batting_team" in the axis x, we using the total "total_runs" in the axis y
sns.boxplot(x = "batting_team", y = "total_runs", data = inning1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
#here we a new graph using the labrery seaborn
#here we using the "batting_team" in the axis x, we using the total "total_runs" in the axis y
sns.boxplot(x = "batting_team", y = "total_runs", data = inning2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %% [markdown]
# ## How many times teams more than 200

# %%
#here we create a new dataframe agrup the clumns "match_id","inning","batting_team","bowling_team"
high_scores = df.groupby(["match_id","inning","batting_team","bowling_team"])["total_runs"].sum().reset_index()
#here we see the new dataframe
high_scores
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           G1          KKR         183
# ...        ...     ...          ...          ...         ...
# 1279       634       2          KKR          SRH         140
# 1280       635       1           G1          SRH         162
# 1281       635       2          SRH           G1         163
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [1284 rows x 5 columns]

# %%
# here we create a new data frame with data frame "high_scores" using a filter "total_runs"> = 200
score_200 = high_scores[high_scores["total_runs"] >= 200]
# here we see the new dataframe
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           G1         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1250       620       1          RCB           G1         248
# 1256       623       1           MI           DD         206
# 1262       626       1          RCB         KXIP         211
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %%
#here we create a new grahp using a labrery seaborn
#here we create a new grahp using a "batting_team" data of my dataframe "score_200" 
sns.countplot(score_200["batting_team"])
# Out:
# /home/monky/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='batting_team', ylabel='count'>

# %%
#here we create a new grahp using a labrery seaborn
#here we create a new grahp using a "bowling_team" data of my dataframe "score_200" 
sns.countplot(score_200["bowling_team"])
# Out:
# /home/monky/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bowling_team', ylabel='count'>

# %% [markdown]
# ## Batsman comparison

# %%
#here we define the variable "balls" 
#We group the column "batsman" with the column "ball", "count" the data, and then convert it to a data frame using the function "reset_index".
balls = df.groupby("batsman")["ball"].count().reset_index()
#here we can see the variable
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
#here we create a variable "runs"
#We group the column "batsman" with the column "batsman_runs", "sum" the data, and then convert it to a data frame using the function "reset_index".
runs = df.groupby("batsman")["batsman_runs"].sum().reset_index()
#here we can see the varible "runs"
runs
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
#here we create a varible "four" this varible is the  our dataframe(df) using the filter "batsman_runs" = 4
four = df[df["batsman_runs"] == 4]
#here we can see the result
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          RCB     1     3      DA Warner
# 8              1       1          SRH          RCB     2     2      DA Warner
# 13             1       1          SRH          RCB     2     7   MC Henriques
# 30             1       1          SRH          RCB     5     5   MC Henriques
# 32             1       1          SRH          RCB     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB          SRH    11     4        V Kohli
# 150407       636       2          RCB          SRH    12     2        V Kohli
# 150418       636       2          RCB          SRH    14     1       KL Rahul
# 150447       636       2          RCB          SRH    18     6    Sachin Baby
# 150459       636       2          RCB          SRH    20     6  Iqbal Abdulla
#
# ...

# %%
#here wecreate a avarible runs_4
#this varible group the column "batsman" and column "batsman_runs" of our dataframe(four), we "count" the data, then covert it to a dataframe using "reset_index"
runs_4 = four.groupby("batsman")["batsman_runs"].count().reset_index()
#here we put a name to the columns
runs_4.columns = ["batsman", "4s"]
#here we can see the result
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
#here we create a varible "six" this varible is the  our dataframe(df) using the filter "batsman_runs" = 6
six = df[df["batsman_runs"] == 6]
#here we can see the result
six
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10             1       1          SRH          RCB     2     4     DA Warner
# 47             1       1          SRH          RCB     8     4  MC Henriques
# 75             1       1          SRH          RCB    13     2  Yuvraj Singh
# 89             1       1          SRH          RCB    15     3  Yuvraj Singh
# 91             1       1          SRH          RCB    15     5  MC Henriques
# ...          ...     ...          ...          ...   ...   ...           ...
# 150395       636       2          RCB          SRH    10     2       V Kohli
# 150413       636       2          RCB          SRH    13     2       V Kohli
# 150428       636       2          RCB          SRH    15     5     SR Watson
# 150440       636       2          RCB          SRH    17     5     STR Binny
# 150453       636       2          RCB          SRH    19     6   Sachin Baby
#
# ...

# %%
#here wecreate a avarible six
#this varible group the column "batsman" and column "batsman_runs" of our dataframe(six), we "count" the data, then covert it to a dataframe using "reset_index"
six = four.groupby("batsman")["batsman_runs"].count().reset_index()
#here we put a name to the columns
six.columns = ["batsman", "6s"]
#here we can see the reusult
six
# Out:
#             batsman   6s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
#here we create a new dataframe(player) concat the dataframes "runs", "balls" ,"runs_4" ,"six" then we set axis = 1 
player = pd.concat([runs, balls.iloc[:,1], runs_4.iloc[:,1], six.iloc[:,1]], axis = 1)
#here we can see the result
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  16.0
# 1        A Chandila             4     7   7.0   7.0
# 2          A Chopra            53    75   1.0   1.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   3.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   NaN   NaN
# 457   Yashpal Singh            47    67   NaN   NaN
# 458     Younis Khan             3     7   NaN   NaN
# 459    Yuvraj Singh          2591  2050   NaN   NaN
# 460          Z Khan           117   141   NaN   NaN
#
# [461 rows x 5 columns]

# %%
#here we use the fillna to convert NaN values to 0
player.fillna(0, inplace = True)

# %%
#here we can see the results 
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  16.0
# 1        A Chandila             4     7   7.0   7.0
# 2          A Chopra            53    75   1.0   1.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   3.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   0.0   0.0
# 457   Yashpal Singh            47    67   0.0   0.0
# 458     Younis Khan             3     7   0.0   0.0
# 459    Yuvraj Singh          2591  2050   0.0   0.0
# 460          Z Khan           117   141   0.0   0.0
#
# [461 rows x 5 columns]

# %%
# here we create a new column "striker_rate", "striker_rate" is "batsman_runs" divided by "ball" 
player["striker_rate"] = player["batsman_runs"]/player["ball"]

player
# Out:
#             batsman  batsman_runs  ball    4s    6s  striker_rate
# 0    A Ashish Reddy           280   196  16.0  16.0      1.428571
# 1        A Chandila             4     7   7.0   7.0      0.571429
# 2          A Chopra            53    75   1.0   1.0      0.706667
# 3       A Choudhary            25    20   5.0   5.0      1.250000
# 4        A Flintoff            62    57   3.0   3.0      1.087719
# ..              ...           ...   ...   ...   ...           ...
# 456     YV Takawale           192   183   0.0   0.0      1.049180
# 457   Yashpal Singh            47    67   0.0   0.0      0.701493
# 458     Younis Khan             3     7   0.0   0.0      0.428571
# 459    Yuvraj Singh          2591  2050   0.0   0.0      1.263902
# 460          Z Khan           117   141   0.0   0.0      0.829787
#
# [461 rows x 6 columns]

# %%
#here we create a new variable "grp"
#here we group the columns "match_id", "batsman", "batting_team" of the our dataframe(df), then we "sum" the data "batsman_runs", then we convert it to dataframe using the function "reset_index"
grp = df.groupby(["match_id", "batsman", "batting_team"])["batsman_runs"].sum().reset_index()
#here we can see the result
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
#here we create a new varible "max"
#here we group the columns "batsman" and "batsman_runs" and see the maximun values of the "batsman_runs", then we convert the varible "max" it to dataframe using the function "reset_index" 
max = grp.groupby("batsman")["batsman_runs"].max().reset_index()
#here we put the names of the columns 
max.colums = ["batsman", "max_runs"]
#here we can see the results 
max
# Out:
# <ipython-input-99-391c600cc0c9>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   max.colums = ["batsman", "max_runs"]
#             batsman  batsman_runs
# 0    A Ashish Reddy            36
# 1        A Chandila             4
# 2          A Chopra            24
# 3       A Choudhary            15
# 4        A Flintoff            24
# ..              ...           ...
# 456     YV Takawale            45
# 457   Yashpal Singh            20
# 458     Younis Khan             3
# 459    Yuvraj Singh            83
# 460          Z Khan            23
#
# [461 rows x 2 columns]

# %%
#here we create a new dataframe concant the "player" dataframe and the "max" dataframe, then we set axis = 1 
player2 = pd.concat([player, max.iloc[:,1]], axis = 1)
#here we can see the result 
player2
# Out:
#             batsman  batsman_runs  ball    4s    6s  striker_rate  \
# 0    A Ashish Reddy           280   196  16.0  16.0      1.428571
# 1        A Chandila             4     7   7.0   7.0      0.571429
# 2          A Chopra            53    75   1.0   1.0      0.706667
# 3       A Choudhary            25    20   5.0   5.0      1.250000
# 4        A Flintoff            62    57   3.0   3.0      1.087719
# ..              ...           ...   ...   ...   ...           ...
# 456     YV Takawale           192   183   0.0   0.0      1.049180
# 457   Yashpal Singh            47    67   0.0   0.0      0.701493
# 458     Younis Khan             3     7   0.0   0.0      0.428571
# 459    Yuvraj Singh          2591  2050   0.0   0.0      1.263902
# 460          Z Khan           117   141   0.0   0.0      0.829787
#
#      batsman_runs
# 0              36
# 1               4
# 2              24
# 3              15
# 4              24
# ..            ...
# 456            45
# ...

# %% [markdown]
# ## Top 10 batsman

# %%
#here we create a new data frame by grouping the columns "batsman", "batsman_runs" and sum the data to the "batsman_runs"
max_runs = df.groupby("batsman")["batsman_runs"].sum()
#here we create a graph using "plot(kind = "bar")" and we put the values in ascending order "(ascending = False)" then we we asked for the top 10 "[:10]"
max_runs.sort_values(ascending = False)[:10].plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='batsman'>

# %% [markdown]
# ## Top  individual scores batsman

# %%
#here we create a new varible agruping the columns "match_id", "batsman", "batting_team" and "sum" the values "batsman_runs", then we convert the varible in dataframe using the function "reset_index", then we asked the values in ascending order 
top_individual = df.groupby(["match_id", "batsman", "batting_team"])["batsman_runs"].sum().reset_index().sort_values(by = "batsman_runs", ascending = False)
#here we see the dataframe using the function "head" and we asked the top 10  
top_individual.head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %% [markdown]
# ## Highest wicket taker

# %%
#here we can se the list of the "dismissal_kind"
df["dismissal_kind"].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
#here we create a varible with the values of the ["dismissal_kind"].unique()
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
#here we create a new dataframe using the our dataframe(df) using the columns in dismissal_kinds as a filter
hwt = df[df["dismissal_kind"].isin(dismissal_kinds)]
#here we can see the result 
hwt
# Out:
#         match_id  inning batting_team bowling_team  over  ball  \
# 11             1       1          SRH          RCB     2     5
# 64             1       1          SRH          RCB    11     3
# 94             1       1          SRH          RCB    16     2
# 116            1       1          SRH          RCB    19     4
# 160            1       2          RCB          SRH     6     4
# ...          ...     ...          ...          ...   ...   ...
# 150402       636       2          RCB          SRH    11     3
# 150416       636       2          RCB          SRH    13     5
# 150422       636       2          RCB          SRH    14     5
# 150432       636       2          RCB          SRH    16     3
# 150438       636       2          RCB          SRH    17     3
#
#                batsman     non_striker             bowler  is_super_over  ...  \
# 11           DA Warner        S Dhawan        A Choudhary              0  ...
# ...

# %%
#here we create a graph that counts the values of each player in the "bowler" column and then finds the top 10
hwt["bowler"].value_counts()[:10].plot(kind = "bar")
# Out:
# <AxesSubplot:>
